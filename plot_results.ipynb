# %%
# In case modules are not yet available, run the following.
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install  -r requirements.txt

# %%
# Make the plots.
# %run plot_results.py
# %run plot_fluxes.py
